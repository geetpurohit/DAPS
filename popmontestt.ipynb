# %%
import pandas as pd
import popmon
from popmon import resources

# open synthetic data
df = pd.read_csv(resources.data("test.csv.gz"), parse_dates=["date"])
df.head()
# Out:
#                         _id                                          address  \
# 0  565ebe61ffa6f757b5029f29   109 Monument Walk, Vicksburg, California, 6247
# 1  565ebe616e073b23430d7052        602 Harkness Avenue, Tyhee, Arizona, 5853
# 2  565ebe6141fdb23a67dd7584    286 Fay Court, Forbestown, Pennsylvania, 6141
# 3  565ebe61c33636f6df907b06  617 Baycliff Terrace, Castleton, Oklahoma, 7714
# 4  565ebe61225511fd3288bb63         262 Scholes Street, Fillmore, Utah, 2905
#
#    age    balance   company                      email eyeColor favoriteFruit  \
# 0   16  $1,333.24    DOGSPA     tamekajoyce@dogspa.com     grey        banana
# 1   57  $3,777.44   APPLICA   rosettaflynn@applica.com    brown        banana
# 2   26  $1,248.97  HOMETOWN  kathiemurray@hometown.com     blue    strawberry
# 3   63  $1,049.77      ISIS       bennetthahn@isis.com    green    strawberry
# 4   74  $2,942.64  FUTURITY  cottoncarson@futurity.com      red    strawberry
#
# ...

# %%
from datetime import datetime
import datetime
import seaborn as sns

# %%
plt.figure( figsize = ( 12, 5))
df[ '7day_rolling_avg' ] = df.age.rolling( 30).mean()
# plot a simple time series plot
# using seaborn.lineplot()
  
# plot using rolling average
sns.lineplot( x = df['date'],
             y =  df['7day_rolling_avg'],
             data = df)
# Out:
# <AxesSubplot:xlabel='date', ylabel='7day_rolling_avg'>

# %%
plt.plot(df.index, df['age'])

# %%
sns.displot(df, x='age', hue = 'gender', multiple="stack")

# %%
report = df.pm_stability_report(time_axis="date", features=["date:age", "date:gender"])
# Out:
# 2022-07-14 09:10:53,256 INFO [histogram_filler_base]: Filling 2 specified histograms. auto-binning.
# 100%|████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 153.85it/s]
# 2022-07-14 09:10:53,272 INFO [hist_splitter]: Splitting histograms "hists" as "split_hists"
# 2022-07-14 09:10:53,276 INFO [hist_comparer]: Comparing "split_hists" with rolling sum of 1 previous histogram(s).
# 2022-07-14 09:10:53,331 INFO [hist_profiler]: Profiling histograms "split_hists" as "profiles"
# 2022-07-14 09:10:53,345 INFO [hist_comparer]: Comparing "split_hists" with reference "split_hists"
# 2022-07-14 09:10:53,398 INFO [pull_calculator]: Comparing "comparisons" with median/mad of reference "comparisons"
# 2022-07-14 09:10:53,430 INFO [pull_calculator]: Comparing "profiles" with median/mad of reference "profiles"
# 2022-07-14 09:10:53,485 INFO [apply_func]: Computing significance of (rolling) trend in means of features
# ...

# %%
report
# Out:
# <div style="position:relative;padding-top:100%;">
#     <iframe srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=en&gt; &lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=generator content=&quot;popmon 1.0.0&quot;&gt;&lt;meta name=description content=&quot;Automatically generated population shift report&quot;&gt;&lt;meta name=url content=https://github.com/ing-bank/popmon&gt;&lt;title&gt;POPMON Report&lt;/title&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/bootstrap@4.3.1/dist/css/bootstrap.min.css&gt;&lt;style&gt;body {
#     padding-top: 56px;
# }
#
# header {
#   padding: 156px 0 100px;
# }
#
# section {
#   padding: 150px 0;
# }
#
# section {
#   padding: 70px 0
# }
#
# a.nav-link {
#   cursor: pointer;
#   font-weight: 300;
# }
#
# .navbar-brand {
#   color: #fff !important;
#   font-weight: 700
# }
#
# .card-body {
#   padding-bottom: 0 !important;
# ...

# %%
import pandas as pd
sns.set(rc={'figure.figsize':(11.7,8.27)})
# open synthetic data
df = pd.read_csv("AirPassengers.xls")
df.head()
sns.lineplot( x = df['Month'],
             y =  df['#Passengers'],
             data = df)
# Out:
# 2022-07-14 09:54:33,593 INFO [category]: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2022-07-14 09:54:33,602 INFO [category]: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# <AxesSubplot:xlabel='Month', ylabel='#Passengers'>

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,1)
ax.hist(df, bins=50, color='lightblue')
# Out:
# 2022-07-14 10:01:37,452 INFO [category]: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2022-07-14 10:01:37,458 INFO [category]: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18356/3078974032.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 fig, ax = plt.subplots(1,1)
# ----> 3 ax.hist(df, bins=50, color='lightblue')
#
# c:\Users\gp\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
# ...
